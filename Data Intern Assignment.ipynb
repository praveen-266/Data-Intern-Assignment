# %%
import pandas as pd
import re
import json

# Read the symptom data from the text file
with open(r'C:\Users\prave\Downloads\Symptom_data.txt', encoding='utf-8') as f:
    symptom_data = f.read()

# Read the JSON file to identify the columns required in the output
with open(r'C:\Users\prave\Downloads\Fever.json', encoding='utf-8') as f:
    fever_json = json.load(f)

# Defining a function to extract the value of a given key from a symptom string
def extract_value(symptom, key):
    start = symptom.find(key) + len(key)
    end = symptom.find('.', start)
    return symptom[start:end].strip()

# Parse the symptom data and create a list of dictionaries
symptoms = []
for symptom in symptom_data.split('►<b>Fever</b>:'):
    if symptom.strip() == '':
        continue
    symptom_dict = {'Symptom': 'Fever'}
    symptom_dict['Duration'] = extract_value(symptom, 'Duration -')
    symptom_dict['Nature of fever'] = extract_value(symptom, 'Nature of fever -')
    symptom_dict['Timing'] = extract_value(symptom, 'Timing -')
    symptom_dict['Severity'] = extract_value(symptom, 'Severity -')
    symptom_dict['Associated symptoms - Cough'] = extract_value(symptom, 'Cough -') if 'Cough -' in symptom else 'Patient denies'
    symptom_dict['Associated symptoms - Abdominal pain'] = extract_value(symptom, 'Abdominal pain -') if 'Abdominal pain -' in symptom else 'Patient denies'
    symptoms.append(symptom_dict)

# Create a Pandas DataFrame from the list of dictionaries
df = pd.DataFrame(symptoms)

# Add a new 'Sr.No' column
df.insert(0, 'Sr.No', range(1, 1 + len(df)))

# Modify the 'Associated symptoms - Cough' and 'Associated symptoms - Abdominal pain' columns
df['Associated symptoms - Cough'] = df['Associated symptoms - Cough'].apply(lambda x: x.split(',')[0].strip() if ',' in x else x)
df['Associated symptoms - Abdominal pain'] = df['Associated symptoms - Abdominal pain'].apply(lambda x: x.split(',')[0].strip() if ',' in x else x)

# Write the DataFrame to an Excel file
df.to_excel('Output.xlsx', index=False)

# %%
df
# Out:
#    Sr.No Symptom Duration                                    Nature of fever  \
# 0      1   Fever  1 Weeks                           Irregular (comes & goes)
# 1      2   Fever   1 Days                                  All day/ Constant
# 2      3   Fever   3 Days  All day/ Constant, Irregular (comes & goes), E...
#
#     Timing  Severity Associated symptoms - Cough  \
# 0  Evening       Low              Patient denies
# 1  All day      High                         Dry
# 2  Evening  Moderate                         Wet
#
#   Associated symptoms - Abdominal pain
# 0                               Middle
# 1                       Patient denies
# 2                                 Left
